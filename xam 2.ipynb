# %%
# importing libraries
import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def seidal (a,x,b):
    # finding length of a(3)
    n = len(a)
    #for loop fro 3 times as to calculate x,y,z
    for j in range (0,n):
        # temp variable d to store b[j]
        d = b[j]
        
        # to calculate respective xi,yi,zi
        for i in range (0,n):
            if(j != i):
                d-=a[j][i] * x[i]
                # updtaing the value of our solution
        x[j] = d/ a[j][j]
    #returning our updated solution
    return x
G = np.zeros((11,3))
# input as number of variable to be solved
for k in range(0,1):
    n = 3 
    a = []
    b = []
    # initial solution depending on n (here n=3)
    x = [0,0,0]
    a = [[3,2,1],[2,3,-1],[1,-2,4]]
    b = [13+k,0,17]
  
    #loop for m times depending on m the error value
    for i in range (400,200):
        seidal( a,x,b)
    # print each time the updated solution
    print(x)
    G[k]=x
# Out:
# [0, 0, 0]

# %%
#problem 2

# importing libraries
import os #interacting with the underlying operating system
import pandas as pd #importing pandas library

import numpy as np
import matplotlib.pyplot as plt

# %%
path = "C:/Users/Prudhvi/Desktop/Python exam 2"
os.chdir(path)
# Read the csv file
fname = 'xam.csv'
a = pd.read_csv(fname)
a.head(65)
# Out:
#    agency_cd  site_no peak_dt year_last_pk ag_gage_ht  ag_gage_ht_cd  \
# 0       USGS          8039100   21-09-1958      15900          17.50
# 1       USGS          8039100   18-04-1959       6100          14.50
# 2       USGS          8039100   24-02-1960       2620          12.77
# 3       USGS          8039100   17-03-1961       5000          13.95
# 4       USGS          8039100   10-12-1961       3200          13.20
# ..       ...              ...          ...        ...            ...
# 60      USGS          8039100   29-03-2018      15:15        6050.00
# 61      USGS          8039100   08-12-2018      12:30        9010.00
# 62      USGS          8039100   20-04-2020      05:15        4960.00
# 63      USGS          8039100   10-05-2021      07:30       13400.00
# 64      USGS          8039100   23-03-2022       3000          12.93
#
#     Unnamed: 5
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 60       14.56
# ...

# %%
# Define function f(x)
def fx(x,y,CdF):
    g = 65
    fdx = (r-0.44)/n+0.12
    return(fdx)

# %%
# compute f(x) versus x
from reliability.Probability_plotting import plotting_positions
q = 65 #cfs
Cd = 0.6
Dr = np.arange(0.01,10,0.1)
# Make a plot
plt.plot(Dr,fDr,'bo')
plt.xlabel('Diameter (ft)')
plt.ylabel('F(x)')
plt.title('Plot of F(x) versus x')
plt.axhline(y = 0, color ="red", linestyle ="--")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2336\2916698108.py in <module>
#       1 # compute f(x) versus x
# ----> 2 from reliability.Probability_plotting import plotting_positions
#       3 q = 65 #cfs
#       4 Cd = 0.6
#       5 Dr = np.arange(0.01,10,0.1)
#
# ModuleNotFoundError: No module named 'reliability'
